# %% [markdown]
# #受難日第一天 20190923
# ##城市超簡單

# %%
print("Hello Mydeargreatteacherrthkophokrtpkohohp")
# Out:
# Hello Mydeargreatteacherrthkophokrtpkohohp

# %%
print("   *    ")
print("  ***      ")
print(" *****          ")
print("*******           ")
print("   *")
print("   *")
print("   *")
# Out:
#    *
#   ***
#  *****
# *******
#    *
#    *
#    *
