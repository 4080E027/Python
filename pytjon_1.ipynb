# %% [markdown]
# #受難日第一天 20190923
# ##城市超簡單

# %%
print(""Hello Mydeargreatteacherrthkophokrtpkohohp)
# Out:
#   File "<ipython-input-3-f08958803a67>", line 1
#     print(""Hello Mydeargreatteacherrthkophokrtpkohohp)
#                 ^
# SyntaxError: invalid syntax

# %%
print("   *    ")
print("  ***      ")
print(" *****          ")
print("*******           ")
print("   *")
print("   *")
print("   *")
# Out:
#    *
#   ***
#  *****
# *******
#    *
#    *
#    *
